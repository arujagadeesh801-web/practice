# %% [markdown]
# ### Variable

# %%
x=5
print(x)
# Out:
# 5

# %%
a = 0o1011
print(a)
print(type(a))
b = 0b1001
print(b)
print(type(b))
c = 0b1111
print(c)
print(str(c))
print(type(c))
d="367"
print(type(d))
print(int(d))
e=7
print(e>7)
print(bool("k"))
print(bin(e))
print(oct(e))
print(float(e))
print(hex(e))
# Out:
# 521
# <class 'int'>
# 9
# <class 'int'>
# 15
# 15
# <class 'int'>
# <class 'str'>
# 367
# False
# True
# 0b111
# 0o7
# 7.0
# 0x7
