# %% [markdown]
# ##pandas

# %%
'''Intro to pandas'''
# Out:
# 'Intro to pandas'

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

df=pd.DataFrame({"Name":["jaga","alex","jack"],
                 "Dept":["cse","ece","Ai"],
                 "CGPA":[9,8.2,7.9]})
print(df)
df[df["CGPA"]>8]
# Out:
#    Name Dept  CGPA
# 0  jaga  cse   9.0
# 1  alex  ece   8.2
# 2  jack   Ai   7.9
#    Name Dept  CGPA
# 0  jaga  cse   9.0
# 1  alex  ece   8.2

# %%
df["email"]=["1334@gmail.com","deesh@gmail.com","jaga@gmail.com"]
print(df)
# Out:
#    Name Dept  CGPA            email
# 0  jaga  cse   9.0   1334@gmail.com
# 1  alex  ece   8.2  deesh@gmail.com
# 2  jack   Ai   7.9   jaga@gmail.com

# %%
df.Name
# Out:
# 0    jaga
# 1    alex
# 2    jack
# Name: Name, dtype: object

# %%
df[df["CGPA"]>8]
# Out:
#    Name Dept  CGPA
# 0  jaga  cse   9.0
# 1  alex  ece   8.2

# %%
df[(df["CGPA"]>=9) & (df["email"] == "1334@gmail.com")]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3489/2971752323.py in <module>
# ----> 1 df[(df["CGPA"]>=9) & (df["email"] == "1334@gmail.com")]
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df=pd.DataFrame({"Name":["jaga","alex","jack"],
                 "Dept":["cse","ece","Ai"], 
                 "CGPA":[9.0,8.2,7.9]}) 
df["email"]=["1334@gmail.com","deesh@gmail.com","jaga@gmail.com"] 
df[(df["CGPA"]>=9) & (df["email"] == "1334@gmail.com")]
# Out:
#    Name Dept  CGPA           email
# 0  jaga  cse   9.0  1334@gmail.com

# %%
df1.shape       
df1["location"].fillna("cbe",inplace=True)
df1["location"].fillna("cbe",inplace=True)


df1["location"].fillna("cbe",inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3489/323914835.py in <module>
# ----> 1 df.shape
#       2 df["location"].fillna("cbe",inplace=True)
#       3 df["location"].fillna("cbe",inplace=True)
#       4
#       5
#
# NameError: name 'df' is not defined

# %%
df1.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3489/2680973753.py in <module>
# ----> 1 df1.columns
#
# NameError: name 'df1' is not defined

# %%
                                                                                                       
    df1["location"].fillna("cbe",inplace=True)

/tmp/ipykernel_10464/3936220401.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.

For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.


  df1["location"].fillna("cbe",inplace=True)
# Out:
#   File "/tmp/ipykernel_3489/237705286.py", line 3
#     tmp/ipykernel_10464/3936220401.py:1:(FutureWarning:, A, value, is, trying, to, be, set, on, a, copy, of, a, DataFrame, or, Series, through, chained, assignment, using, an, inplace, method.)
#                                   ^
# SyntaxError: invalid decimal literal

# %%
import pandas as pd
df = pd.read_csv("order.csv")
a=pd.DataFrame(df)
a
# Out:
#      order_id user_id restaurant_id  order_date  total_amount  \
# 0     ORD0001  USR002        RST007  01/04/2024          2188
# 1     ORD1933  USR080        RST007  26/03/2025           846
# 2     ORD1946  USR038        RST007  28/03/2025          1431
# 3     ORD1265  USR102        RST007  21/11/2024          1231
# 4     ORD1694  USR124        RST007  09/02/2025           523
# ...       ...     ...           ...         ...           ...
# 1963  ORD1068  USR125        RST073  12/10/2024          2359
# 1964  ORD0429  USR194        RST073  17/06/2024             0
# 1965  ORD1438  USR194        RST073  23/12/2024          1879
# 1966  ORD1325  USR090        RST073  01/12/2024          1397
# 1967  ORD1968  USR145        RST046  2025-05-28           560
#
#                                           items_ordered    payment_method  \
# 0                Fried Rice, Masala Dosa, Hakka Noodles       Credit Card
# ...

# %%
df = pd.read_csv("ordered1.csv")
b=pd.DataFrame(df)
b
# Out:
#      order_id user_id restaurant_id  order_date  total_amount  \
# 0     ORD0001  USR002        RST007  01/04/2024          2188
# 1     ORD1933  USR080        RST007  26/03/2025           846
# 2     ORD1946  USR038        RST007  28/03/2025          1431
# 3     ORD1265  USR102        RST007  21/11/2024          1231
# 4     ORD1694  USR124        RST007  09/02/2025           523
# ...       ...     ...           ...         ...           ...
# 1963  ORD1068  USR125        RST073  12/10/2024          2359
# 1964  ORD0429  USR194        RST073  17/06/2024             0
# 1965  ORD1438  USR194        RST073  23/12/2024          1879
# 1966  ORD1325  USR090        RST073  01/12/2024          1397
# 1967  ORD1968  USR145        RST046  2025-05-28           560
#
#                                           items_ordered    payment_method  \
# 0                Fried Rice, Masala Dosa, Hakka Noodles       Credit Card
# ...
